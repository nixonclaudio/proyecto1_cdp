# %% [markdown]
# # Proyecto1

# %% [markdown]
# ## Recordar que el primer paso que se debe hacer es crear el nuevo repositorio en git

# %% [markdown]
# ## El siguiente paso que se debe hacer es desde la terminal (cmd), ingresar a la carpeta donde estoy trabajando en mi computadora, y clonar el repositorio que cree con el url que me proporsiona git.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
! git add .

# %%
! git commit -m "Este es mi primer commit del proyecto"
# Out:
# [main f631fd9] Este es mi primer commit del proyecto
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 proyecto1_cdp.ipynb

# %%
! git push
# Out:
# Everything up-to-date

# %%
! git add .
! git commit -m "Guardar notebook"
! git push
# Out:
# ...
# [main a8c0f6b] Guardar notebook
#  1 file changed, 80 insertions(+)
# To https://github.com/nixonclaudio/proyecto1_cdp.git
#    f631fd9..a8c0f6b  main -> main
